# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import os

# %matplotlib inline

# %%
df = pd.read_csv('labels.csv')[['file_name', 'bbox']].values.tolist()[:5]
df
# Out:
# [['100013282.jpg',
#   '[934.0000000000097, 144.82228672769534, 238.24562254582438, 330.0662796338281]'],
#  ['100016175.jpg',
#   '[1094.0513571635438, 422.91772295627203, 55.45378576262131, 71.31039238064413]'],
#  ['10004189.jpg',
#   '[419.93871061403877, 269.1250391680045, 377.1906900618241, 491.11567140388684]'],
#  ['100104575.jpg',
#   '[1490.6909678848915, 676.0000000000097, 37.55392769189032, 70.33067590805737]'],
#  ['100104600.jpg',
#   '[549.169724453414, 92.52040334013152, 306.8821357962342, 437.365818496933]']]

# %%
path = 'yolo_dataset/train/images/'
img = cv2.imread(path+'100013282.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
x1 = 934#-238//2
x2 = 934+238#//2
y1 = 145#-330//2
y2 = 145+330#//2
img = cv2.rectangle(img, (x1, y1), (x2, y2), (255, 255, 0), 1)
plt.imshow(img)
