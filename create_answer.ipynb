# %%
import pandas as pd
import json
import os
import cv2
import torch
from ultralytics import YOLO
from matplotlib import pyplot as plt
import time
import numpy as np

# %%
info_label = {
    'age': ['20-30s', '40-50s', 'Baby', 'Kid', 'Senior', 'Teenager'],
    'race': ['Caucasian', 'Mongoloid', 'Negroid'],
    'masked': ['masked', 'unmasked'],
    'skintone': ['dark', 'light', 'mid-dark', 'mid-light'],
    'emotion': ['Anger', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise'],
    'gender': ['Female', 'Male']
}

# %%
def imshow_np_image(img):
    plt.imshow(img[:,:,::-1])    
    plt.show()

def tensor_to_float(lis):
    # lis = [int(np.round(i.cpu().detach().numpy()) for i in lis)]
    lis = [float(i.cpu().detach().numpy()) for i in lis]
    return lis
    
def process_out_detect(img, results):
    bbox_lis = []
    for r in results:
        boxes = r.boxes
        for i, box in enumerate(boxes):
            x, y, w, h = box.xywh[0]

            bbox_lis.append(tensor_to_float([x-w/2, y-h/2, w, h]))

            cv2.rectangle(img, (int(x-w/2),int(y-h/2)), (int(x+w/2),int(y+h/2)), (0,255,0), 3)
            # cv2.putText(img, str(i+1) ,(x1,y1+20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 1)
    return bbox_lis

def sample_values(lis):
    print(lis)
    lis = list(lis)
    while len(lis) < 30:
        lis.append(-1)
    return lis

def convert_to_text(key, index):
    return info_label[key][index]

def procees_out_cls(results, index_box):
    preds = {}
    num_cate = iter([6,3,2,4,7,2])
    for key in results.keys():
        cur_cate = next(num_cate)
        pred = results[key]
        pred = pred[:, (index_box * cur_cate):((index_box + 1) * cur_cate)]
        pred = torch.softmax(pred, dim= -1)
        pred = torch.argmax(pred, dim= -1)
        index = int(pred.cpu().detach().numpy())
        preds[key] = convert_to_text(key, index)
    return preds

# %%
image_id = json.load(open('file_name_to_image_id.json'))

# %%
yolo = YOLO('best.pt')
img = cv2.imread('public_test/100147591.jpg')
a = yolo(img)
# Out:
# 0: 224x320 1 face, 12.5ms
# Speed: 5.2ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)

# %%
path = 'public_test/'
all_preds = []
times = []
for index, name in enumerate(image_id.keys()):
    print(index)
    name_id = image_id[name]
    img = cv2.imread(path + name)
    s = time.time()
    results = yolo(img)
    e = time.time()
    times.append(e-s)

    bbox_lis = []
    for r in results[0]:
        boxes = r.boxes
        for i, box in enumerate(boxes):
            x, y, w, h = box.xywh[0]
            bbox_lis.append(tensor_to_float([x-w/2, y-h/2, w, h]))

    preds = {}
    for i in range(len(bbox_lis)):
        num_cate = iter([6,3,2,4,7,2])
        for key in results[1].keys():
            cur_cate = next(num_cate)
            pred = results[1][key]
            pred = pred[:, (i * cur_cate):((i + 1) * cur_cate)]
            pred = torch.softmax(pred, dim= -1)
            pred = torch.argmax(pred, dim= -1)
            index = int(pred.cpu().detach().numpy())
            preds[key] = convert_to_text(key, index)
        all_preds.append([name, bbox_lis[i], name_id, preds['race'], preds['age'], preds['emotion'], preds['gender'], preds['skintone'], preds['masked']])
# Out:
# 0
#
# 0: 224x320 1 face, 113.1ms
# Speed: 4.6ms preprocess, 113.1ms inference, 4.3ms postprocess per image at shape (1, 3, 224, 320)
# 1
#
# 0: 224x320 1 face, 19.8ms
# Speed: 0.9ms preprocess, 19.8ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 2
#
# 0: 224x320 1 face, 12.9ms
# Speed: 5.9ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 3
#
# 0: 224x320 1 face, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 5.6ms postprocess per image at shape (1, 3, 224, 320)
# 4
#
# 0: 224x320 (no detections), 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 5
#
# 0: 224x320 1 face, 41.0ms
# Speed: 5.3ms preprocess, 41.0ms inference, 1.9ms postprocess per image at shape (1, 3, 224, 320)
# 6
#
# 0: 224x320 1 face, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 320)
# 7
#
# 0: 224x320 1 face, 12.5ms
# Speed: 0.8ms preprocess, 12.5ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 320)
# 8
#
# 0: 224x320 1 face, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 9
#
# 0: 224x320 1 face, 16.0ms
# Speed: 5.9ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 10
#
# 0: 224x320 1 face, 13.2ms
# Speed: 5.2ms preprocess, 13.2ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 320)
# 11
#
# 0: 224x320 1 face, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 12
#
# 0: 224x320 1 face, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 320)
# 13
#
# 0: 224x320 1 face, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 320)
# 14
#
# 0: 224x320 1 face, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 15
#
# 0: 224x320 1 face, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 4.7ms postprocess per image at shape (1, 3, 224, 320)
# 16
#
# 0: 224x320 1 face, 13.2ms
# Speed: 5.4ms preprocess, 13.2ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 320)
# 17
#
# 0: 320x224 1 face, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 224)
# 18
#
# 0: 224x320 1 face, 18.9ms
# Speed: 0.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 19
#
# 0: 288x320 1 face, 17.1ms
# Speed: 5.2ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 320)
# 20
#
# 0: 224x320 (no detections), 15.0ms
# Speed: 5.3ms preprocess, 15.0ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 21
#
# 0: 224x320 1 face, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 22
#
# 0: 320x320 1 face, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
# 23
#
# 0: 224x320 1 face, 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
# 24
#
# 0: 320x224 1 face, 13.3ms
# Speed: 0.9ms preprocess, 13.3ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 224)
# 25
#
# 0: 224x320 1 face, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 320)
# 26
#
# 0: 320x224 1 face, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 27
#
# 0: 224x320 1 face, 17.3ms
# Speed: 0.6ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 28
#
# 0: 224x320 1 face, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 5.5ms postprocess per image at shape (1, 3, 224, 320)
# 29
#
# 0: 224x320 1 face, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 5.8ms postprocess per image at shape (1, 3, 224, 320)
# 30
#
# 0: 224x320 2 faces, 13.3ms
# Speed: 5.5ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 31
#
# 0: 320x224 1 face, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 224)
# 32
#
# 0: 320x224 1 face, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 224)
# 33
#
# 0: 192x320 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# 34
#
# 0: 224x320 1 face, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 320)
# 35
#
# 0: 256x320 1 face, 16.6ms
# Speed: 1.5ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 320)
# 36
#
# 0: 224x320 1 face, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 320)
# 37
#
# 0: 224x320 1 face, 12.1ms
# Speed: 6.2ms preprocess, 12.1ms inference, 2.8ms postprocess per image at shape (1, 3, 224, 320)
# 38
#
# 0: 320x224 1 face, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 224)
# 39
#
# 0: 224x320 1 face, 13.7ms
# Speed: 5.2ms preprocess, 13.7ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 320)
# 40
#
# 0: 320x224 1 face, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 41
#
# 0: 224x320 1 face, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 320)
# 42
#
# 0: 256x320 1 face, 17.7ms
# Speed: 1.2ms preprocess, 17.7ms inference, 3.6ms postprocess per image at shape (1, 3, 256, 320)
# 43
#
# 0: 224x320 1 face, 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 320)
# 44
#
# 0: 224x320 1 face, 12.4ms
# Speed: 6.0ms preprocess, 12.4ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 320)
# 45
#
# 0: 224x320 1 face, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 5.2ms postprocess per image at shape (1, 3, 224, 320)
# 46
#
# 0: 224x320 1 face, 14.9ms
# Speed: 0.6ms preprocess, 14.9ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 320)
# 47
#
# 0: 224x320 1 face, 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 320)
# 48
#
# 0: 224x320 1 face, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 49
#
# 0: 224x320 1 face, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 50
#
# 0: 224x320 1 face, 10.2ms
# Speed: 0.9ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 51
#
# 0: 320x224 1 face, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 224)
# 52
#
# 0: 224x320 1 face, 15.3ms
# Speed: 1.4ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 53
#
# 0: 320x224 1 face, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 224)
# 54
#
# 0: 320x224 1 face, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 55
#
# 0: 320x224 1 face, 13.2ms
# Speed: 2.3ms preprocess, 13.2ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 224)
# 56
#
# 0: 224x320 1 face, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 57
#
# 0: 224x320 1 face, 15.0ms
# Speed: 1.1ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 58
#
# 0: 320x224 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 224)
# 59
#
# 0: 256x320 1 face, 18.5ms
# Speed: 0.0ms preprocess, 18.5ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 320)
# 60
#
# 0: 320x224 1 face, 14.6ms
# Speed: 5.5ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 61
#
# 0: 320x224 1 face, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 224)
# 62
#
# 0: 320x224 1 face, 12.5ms
# Speed: 6.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 63
#
# 0: 320x320 1 face, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 320)
# 64
#
# 0: 224x320 1 face, 16.2ms
# Speed: 3.2ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 65
#
# 0: 224x320 1 face, 21.5ms
# Speed: 6.2ms preprocess, 21.5ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 320)
# 66
#
# 0: 224x320 1 face, 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 2.7ms postprocess per image at shape (1, 3, 224, 320)
# 67
#
# 0: 320x224 1 face, 17.5ms
# Speed: 1.1ms preprocess, 17.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 68
#
# 0: 320x224 1 face, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 224)
# 69
#
# 0: 224x320 1 face, 13.0ms
# Speed: 5.4ms preprocess, 13.0ms inference, 7.8ms postprocess per image at shape (1, 3, 224, 320)
# 70
#
# 0: 224x320 1 face, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 320)
# 71
#
# 0: 320x224 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 224)
# 72
#
# 0: 224x320 1 face, 15.1ms
# Speed: 5.3ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 73
#
# 0: 224x320 1 face, 12.2ms
# Speed: 4.9ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 320)
# 74
#
# 0: 320x224 1 face, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 224)
# 75
#
# 0: 320x224 1 face, 13.3ms
# Speed: 0.0ms preprocess, 13.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 224)
# 76
#
# 0: 320x224 1 face, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 77
#
# 0: 320x224 1 face, 14.6ms
# Speed: 0.8ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 78
#
# 0: 224x320 1 face, 12.1ms
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 79
#
# 0: 320x224 1 face, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 80
#
# 0: 320x224 1 face, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 224)
# 81
#
# 0: 320x224 1 face, 12.5ms
# Speed: 5.3ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 82
#
# 0: 224x320 1 face, 15.7ms
# Speed: 0.7ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 83
#
# 0: 320x224 1 face, 13.2ms
# Speed: 4.8ms preprocess, 13.2ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 224)
# 84
#
# 0: 256x320 1 face, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
# 85
#
# 0: 224x320 1 face, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 320)
# 86
#
# 0: 224x320 1 face, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 87
#
# 0: 320x224 1 face, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 224)
# 88
#
# 0: 320x224 1 face, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 224)
# 89
#
# 0: 224x320 1 face, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 320)
# 90
#
# 0: 224x320 1 face, 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 320)
# 91
#
# 0: 320x224 1 face, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 92
#
# 0: 320x224 1 face, 14.2ms
# Speed: 4.4ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 93
#
# 0: 320x224 1 face, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 94
#
# 0: 224x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 95
#
# 0: 320x224 1 face, 12.9ms
# Speed: 3.5ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 224)
# 96
#
# 0: 224x320 1 face, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 97
#
# 0: 224x320 1 face, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 98
#
# 0: 224x320 1 face, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 99
#
# 0: 224x320 1 face, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 320)
# 100
#
# 0: 224x320 1 face, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 5.5ms postprocess per image at shape (1, 3, 224, 320)
# 101
#
# 0: 224x320 1 face, 13.3ms
# Speed: 5.5ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 102
#
# 0: 224x320 (no detections), 15.3ms
# Speed: 0.7ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 103
#
# 0: 320x224 1 face, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 224)
# 104
#
# 0: 224x320 1 face, 12.3ms
# Speed: 6.3ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 105
#
# 0: 224x320 1 face, 4.1ms
# Speed: 10.5ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 106
#
# 0: 320x224 1 face, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 14.5ms postprocess per image at shape (1, 3, 320, 224)
# 107
#
# 0: 224x320 1 face, 21.7ms
# Speed: 0.0ms preprocess, 21.7ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 320)
# 108
#
# 0: 320x224 1 face, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 109
#
# 0: 320x224 1 face, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 224)
# 110
#
# 0: 224x320 1 face, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 111
#
# 0: 224x320 1 face, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 112
#
# 0: 224x320 1 face, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 113
#
# 0: 320x320 1 face, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 320)
# 114
#
# 0: 320x224 1 face, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 115
#
# 0: 320x224 1 face, 15.7ms
# Speed: 5.2ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 224)
# 116
#
# 0: 224x320 1 face, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 117
#
# 0: 224x320 1 face, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 118
#
# 0: 224x320 1 face, 18.3ms
# Speed: 5.3ms preprocess, 18.3ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 320)
# 119
#
# 0: 320x256 1 face, 10.2ms
# Speed: 3.1ms preprocess, 10.2ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 256)
# 120
#
# 0: 224x320 1 face, 17.2ms
# Speed: 7.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 121
#
# 0: 224x320 1 face, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 4.4ms postprocess per image at shape (1, 3, 224, 320)
# 122
#
# 0: 320x224 1 face, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 224)
# 123
#
# 0: 320x224 1 face, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 224)
# 124
#
# 0: 320x224 1 face, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 224)
# 125
#
# 0: 224x320 1 face, 12.3ms
# Speed: 6.3ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 126
#
# 0: 224x320 1 face, 15.2ms
# Speed: 0.6ms preprocess, 15.2ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 320)
# 127
#
# 0: 320x224 1 face, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 224)
# 128
#
# 0: 320x224 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 224)
# 129
#
# 0: 224x320 2 faces, 14.2ms
# Speed: 4.8ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 130
#
# 0: 320x224 1 face, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 224)
# 131
#
# 0: 224x320 1 face, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 132
#
# 0: 320x224 1 face, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 224)
# 133
#
# 0: 224x320 1 face, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 134
#
# 0: 224x320 1 face, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 5.5ms postprocess per image at shape (1, 3, 224, 320)
# 135
#
# 0: 224x320 1 face, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 4.2ms postprocess per image at shape (1, 3, 224, 320)
# 136
#
# 0: 320x224 1 face, 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 224)
# 137
#
# 0: 320x256 1 face, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 256)
# 138
#
# 0: 224x320 1 face, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 320)
# 139
#
# 0: 320x224 1 face, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 140
#
# 0: 224x320 1 face, 11.8ms
# Speed: 1.1ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 141
#
# 0: 224x320 1 face, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 7.3ms postprocess per image at shape (1, 3, 224, 320)
# 142
#
# 0: 224x320 1 face, 12.7ms
# Speed: 6.4ms preprocess, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 224, 320)
# 143
#
# 0: 320x224 1 face, 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 224)
# 144
#
# 0: 224x320 2 faces, 13.5ms
# Speed: 1.4ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 145
#
# 0: 320x224 1 face, 16.7ms
# Speed: 0.8ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 146
#
# 0: 224x320 1 face, 13.3ms
# Speed: 5.3ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 147
#
# 0: 224x320 1 face, 24.4ms
# Speed: 0.0ms preprocess, 24.4ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 320)
# 148
#
# 0: 224x320 1 face, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 320)
# 149
#
# 0: 224x320 1 face, 12.0ms
# Speed: 6.3ms preprocess, 12.0ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 320)
# 150
#
# 0: 224x320 1 face, 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 6.1ms postprocess per image at shape (1, 3, 224, 320)
# 151
#
# 0: 224x320 1 face, 36.2ms
# Speed: 6.7ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 152
#
# 0: 224x320 1 face, 35.8ms
# Speed: 0.8ms preprocess, 35.8ms inference, 7.0ms postprocess per image at shape (1, 3, 224, 320)
# 153
#
# 0: 224x320 1 face, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 154
#
# 0: 320x224 2 faces, 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 224)
# 155
#
# 0: 224x320 1 face, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 156
#
# 0: 224x320 1 face, 39.3ms
# Speed: 0.0ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 320)
# 157
#
# 0: 320x224 1 face, 41.4ms
# Speed: 2.0ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 158
#
# 0: 320x224 1 face, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 159
#
# 0: 224x320 1 face, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 160
#
# 0: 224x320 1 face, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 320)
# 161
#
# 0: 224x320 1 face, 14.3ms
# Speed: 0.0ms preprocess, 14.3ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 320)
# 162
#
# 0: 224x320 2 faces, 11.3ms
# Speed: 0.9ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 320)
# 163
#
# 0: 320x224 1 face, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 164
#
# 0: 320x224 1 face, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 224)
# 165
#
# 0: 224x320 1 face, 14.1ms
# Speed: 1.6ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 166
#
# 0: 320x224 1 face, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 224)
# 167
#
# 0: 320x224 1 face, 12.3ms
# Speed: 1.1ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 224)
# 168
#
# 0: 224x320 1 face, 12.8ms
# Speed: 0.0ms preprocess, 12.8ms inference, 4.5ms postprocess per image at shape (1, 3, 224, 320)
# 169
#
# 0: 224x320 1 face, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 170
#
# 0: 224x320 1 face, 11.1ms
# Speed: 0.9ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 171
#
# 0: 224x320 1 face, 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 172
#
# 0: 224x320 1 face, 13.8ms
# Speed: 0.5ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 320)
# 173
#
# 0: 224x320 1 face, 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 174
#
# 0: 224x320 1 face, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 175
#
# 0: 256x320 1 face, 14.8ms
# Speed: 0.9ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
# 176
#
# 0: 224x320 1 face, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 177
#
# 0: 320x224 1 face, 12.1ms
# Speed: 0.0ms preprocess, 12.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 224)
# 178
#
# 0: 320x224 1 face, 7.2ms
# Speed: 1.3ms preprocess, 7.2ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 224)
# 179
#
# 0: 192x320 1 face, 12.4ms
# Speed: 2.1ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
# 180
#
# 0: 224x320 1 face, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 4.5ms postprocess per image at shape (1, 3, 224, 320)
# 181
#
# 0: 224x320 1 face, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 182
#
# 0: 224x320 1 face, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 183
#
# 0: 224x320 1 face, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 320)
# 184
#
# 0: 224x320 1 face, 11.1ms
# Speed: 1.1ms preprocess, 11.1ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 185
#
# 0: 224x320 1 face, 12.1ms
# Speed: 1.1ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 186
#
# 0: 320x224 1 face, 10.1ms
# Speed: 0.8ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 187
#
# 0: 320x224 1 face, 12.6ms
# Speed: 0.0ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 224)
# 188
#
# 0: 320x224 1 face, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 189
#
# 0: 224x320 1 face, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 320)
# 190
#
# 0: 224x320 1 face, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 191
#
# 0: 224x320 1 face, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 192
#
# 0: 320x224 1 face, 14.5ms
# Speed: 0.9ms preprocess, 14.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 224)
# 193
#
# 0: 224x320 1 face, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 320)
# 194
#
# 0: 224x320 1 face, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 195
#
# 0: 224x320 1 face, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 5.2ms postprocess per image at shape (1, 3, 224, 320)
# 196
#
# 0: 224x320 1 face, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 5.8ms postprocess per image at shape (1, 3, 224, 320)
# 197
#
# 0: 224x320 1 face, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 198
#
# 0: 224x320 1 face, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 5.8ms postprocess per image at shape (1, 3, 224, 320)
# 199
#
# 0: 224x320 1 face, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 320)
# 200
#
# 0: 320x256 1 face, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 256)
# 201
#
# 0: 224x320 1 face, 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 7.2ms postprocess per image at shape (1, 3, 224, 320)
# 202
#
# 0: 224x320 1 face, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 320)
# 203
#
# 0: 224x320 1 face, 10.7ms
# Speed: 1.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 204
#
# 0: 288x320 1 face, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 320)
# 205
#
# 0: 320x224 1 face, 14.2ms
# Speed: 3.1ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 206
#
# 0: 224x320 1 face, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 207
#
# 0: 320x224 1 face, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 208
#
# 0: 224x320 1 face, 13.7ms
# Speed: 1.9ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 209
#
# 0: 224x320 1 face, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 210
#
# 0: 256x320 1 face, 4.1ms
# Speed: 2.0ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
# 211
#
# 0: 320x224 1 face, 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 224)
# 212
#
# 0: 320x224 1 face, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 213
#
# 0: 320x224 1 face, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 224)
# 214
#
# 0: 256x320 1 face, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 320)
# 215
#
# 0: 320x224 1 face, 18.8ms
# Speed: 0.0ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 216
#
# 0: 320x224 1 face, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 217
#
# 0: 224x320 1 face, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 218
#
# 0: 256x320 1 face, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
# 219
#
# 0: 224x320 1 face, 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 320)
# 220
#
# 0: 224x320 1 face, 14.2ms
# Speed: 1.5ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 221
#
# 0: 224x320 1 face, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 222
#
# 0: 224x320 1 face, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 320)
# 223
#
# 0: 320x224 1 face, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 224
#
# 0: 224x320 1 face, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 320)
# 225
#
# 0: 224x320 1 face, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 320)
# 226
#
# 0: 224x320 1 face, 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 227
#
# 0: 224x320 1 face, 17.4ms
# Speed: 0.5ms preprocess, 17.4ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 320)
# 228
#
# 0: 224x320 1 face, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 5.8ms postprocess per image at shape (1, 3, 224, 320)
# 229
#
# 0: 224x320 1 face, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 320)
# 230
#
# 0: 320x256 1 face, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 256)
# 231
#
# 0: 224x320 1 face, 14.5ms
# Speed: 0.9ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 232
#
# 0: 224x320 1 face, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 320)
# 233
#
# 0: 320x224 1 face, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 224)
# 234
#
# 0: 256x320 1 face, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 256, 320)
# 235
#
# 0: 224x320 1 face, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 236
#
# 0: 224x320 1 face, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 320)
# 237
#
# 0: 320x256 1 face, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 256)
# 238
#
# 0: 224x320 1 face, 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 239
#
# 0: 224x320 1 face, 4.2ms
# Speed: 2.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 240
#
# 0: 320x224 1 face, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 241
#
# 0: 320x224 1 face, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 242
#
# 0: 224x320 1 face, 11.9ms
# Speed: 6.3ms preprocess, 11.9ms inference, 5.6ms postprocess per image at shape (1, 3, 224, 320)
# 243
#
# 0: 224x320 1 face, 14.4ms
# Speed: 7.2ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 244
#
# 0: 224x320 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 7.4ms postprocess per image at shape (1, 3, 224, 320)
# 245
#
# 0: 224x320 1 face, 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 320)
# 246
#
# 0: 320x256 1 face, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 256)
# 247
#
# 0: 224x320 1 face, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 248
#
# 0: 224x320 (no detections), 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 249
#
# 0: 224x320 1 face, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 5.9ms postprocess per image at shape (1, 3, 224, 320)
# 250
#
# 0: 224x320 (no detections), 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 320)
# 251
#
# 0: 320x224 1 face, 8.4ms
# Speed: 1.1ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 252
#
# 0: 320x288 1 face, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 288)
# 253
#
# 0: 224x320 1 face, 13.2ms
# Speed: 0.9ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 254
#
# 0: 224x320 1 face, 2.1ms
# Speed: 1.1ms preprocess, 2.1ms inference, 12.1ms postprocess per image at shape (1, 3, 224, 320)
# 255
#
# 0: 224x320 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 256
#
# 0: 224x320 1 face, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 257
#
# 0: 224x320 1 face, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 258
#
# 0: 224x320 1 face, 13.0ms
# Speed: 5.4ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 259
#
# 0: 224x320 1 face, 11.9ms
# Speed: 6.2ms preprocess, 11.9ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 320)
# 260
#
# 0: 224x320 1 face, 13.8ms
# Speed: 6.5ms preprocess, 13.8ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 261
#
# 0: 320x224 1 face, 17.4ms
# Speed: 5.2ms preprocess, 17.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 224)
# 262
#
# 0: 320x224 (no detections), 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 263
#
# 0: 224x320 1 face, 12.4ms
# Speed: 1.1ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 264
#
# 0: 320x224 1 face, 16.3ms
# Speed: 1.1ms preprocess, 16.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 224)
# 265
#
# 0: 224x320 1 face, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 266
#
# 0: 224x320 1 face, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 267
#
# 0: 320x288 1 face, 17.4ms
# Speed: 6.2ms preprocess, 17.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 288)
# 268
#
# 0: 320x288 1 face, 14.2ms
# Speed: 1.1ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 288)
# 269
#
# 0: 224x320 1 face, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
# 270
#
# 0: 224x320 1 face, 14.4ms
# Speed: 2.9ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 224, 320)
# 271
#
# 0: 224x320 1 face, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 272
#
# 0: 224x320 1 face, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 5.4ms postprocess per image at shape (1, 3, 224, 320)
# 273
#
# 0: 320x224 1 face, 15.7ms
# Speed: 5.3ms preprocess, 15.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 224)
# 274
#
# 0: 320x224 1 face, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 275
#
# 0: 224x320 1 face, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 276
#
# 0: 320x224 1 face, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 277
#
# 0: 224x320 1 face, 36.6ms
# Speed: 2.1ms preprocess, 36.6ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 320)
# 278
#
# 0: 224x320 1 face, 20.9ms
# Speed: 1.9ms preprocess, 20.9ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 320)
# 279
#
# 0: 224x320 (no detections), 23.1ms
# Speed: 1.1ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 280
#
# 0: 224x320 1 face, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 281
#
# 0: 224x320 1 face, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 282
#
# 0: 224x320 1 face, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 6.3ms postprocess per image at shape (1, 3, 224, 320)
# 283
#
# 0: 320x224 1 face, 10.6ms
# Speed: 1.2ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 284
#
# 0: 224x320 1 face, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 285
#
# 0: 224x320 1 face, 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 286
#
# 0: 320x224 1 face, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 287
#
# 0: 256x320 1 face, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
# 288
#
# 0: 224x320 (no detections), 17.4ms
# Speed: 0.9ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 289
#
# 0: 224x320 1 face, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 290
#
# 0: 192x320 1 face, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# 291
#
# 0: 224x320 1 face, 18.1ms
# Speed: 5.5ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 292
#
# 0: 224x320 1 face, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
# 293
#
# 0: 256x320 1 face, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 320)
# 294
#
# 0: 224x320 1 face, 13.3ms
# Speed: 0.7ms preprocess, 13.3ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 320)
# 295
#
# 0: 320x224 1 face, 19.2ms
# Speed: 0.8ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 296
#
# 0: 224x320 1 face, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 320)
# 297
#
# 0: 224x320 1 face, 12.2ms
# Speed: 5.3ms preprocess, 12.2ms inference, 4.3ms postprocess per image at shape (1, 3, 224, 320)
# 298
#
# 0: 224x320 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 299
#
# 0: 224x320 1 face, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 300
#
# 0: 224x320 1 face, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 301
#
# 0: 320x224 1 face, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 224)
# 302
#
# 0: 224x320 1 face, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 303
#
# 0: 320x224 1 face, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 304
#
# 0: 320x224 1 face, 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 224)
# 305
#
# 0: 224x320 1 face, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 306
#
# 0: 320x256 1 face, 13.1ms
# Speed: 5.2ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 256)
# 307
#
# 0: 224x320 1 face, 14.1ms
# Speed: 6.3ms preprocess, 14.1ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 308
#
# 0: 320x224 1 face, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 224)
# 309
#
# 0: 320x224 1 face, 15.2ms
# Speed: 0.7ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 310
#
# 0: 320x224 1 face, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 224)
# 311
#
# 0: 320x224 1 face, 13.0ms
# Speed: 5.2ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 224)
# 312
#
# 0: 224x320 1 face, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
# 313
#
# 0: 224x320 1 face, 16.8ms
# Speed: 1.1ms preprocess, 16.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 320)
# 314
#
# 0: 224x320 1 face, 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 320)
# 315
#
# 0: 224x320 1 face, 19.7ms
# Speed: 1.1ms preprocess, 19.7ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 316
#
# 0: 224x320 1 face, 24.5ms
# Speed: 0.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 317
#
# 0: 224x320 1 face, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.8ms postprocess per image at shape (1, 3, 224, 320)
# 318
#
# 0: 224x320 1 face, 17.2ms
# Speed: 0.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 319
#
# 0: 224x320 1 face, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 320)
# 320
#
# 0: 224x320 1 face, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 5.2ms postprocess per image at shape (1, 3, 224, 320)
# 321
#
# 0: 320x224 1 face, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 322
#
# 0: 320x224 1 face, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 323
#
# 0: 224x320 1 face, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
# 324
#
# 0: 224x320 1 face, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 320)
# 325
#
# 0: 320x224 1 face, 18.2ms
# Speed: 0.0ms preprocess, 18.2ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 224)
# 326
#
# 0: 224x320 1 face, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 320)
# 327
#
# 0: 224x320 1 face, 13.3ms
# Speed: 1.2ms preprocess, 13.3ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 320)
# 328
#
# 0: 224x320 1 face, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 224, 320)
# 329
#
# 0: 224x320 1 face, 14.2ms
# Speed: 1.1ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 330
#
# 0: 320x224 1 face, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 224)
# 331
#
# 0: 224x320 1 face, 22.9ms
# Speed: 2.3ms preprocess, 22.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
# 332
#
# 0: 224x320 1 face, 13.4ms
# Speed: 1.8ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 333
#
# 0: 320x224 1 face, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 334
#
# 0: 224x320 (no detections), 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 335
#
# 0: 320x224 1 face, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 224)
# 336
#
# 0: 224x320 1 face, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 320)
# 337
#
# 0: 320x224 1 face, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 224)
# 338
#
# 0: 224x320 1 face, 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 339
#
# 0: 320x224 1 face, 19.5ms
# Speed: 1.8ms preprocess, 19.5ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 224)
# 340
#
# 0: 224x320 1 face, 24.3ms
# Speed: 6.4ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 320)
# 341
#
# 0: 320x224 1 face, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 224)
# 342
#
# 0: 224x320 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 343
#
# 0: 224x320 2 faces, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 344
#
# 0: 224x320 1 face, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 345
#
# 0: 224x320 1 face, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 5.0ms postprocess per image at shape (1, 3, 224, 320)
# 346
#
# 0: 224x320 1 face, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 347
#
# 0: 224x320 1 face, 14.0ms
# Speed: 2.9ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
# 348
#
# 0: 224x320 1 face, 15.2ms
# Speed: 3.1ms preprocess, 15.2ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# 349
#
# 0: 224x320 1 face, 10.5ms
# Speed: 1.1ms preprocess, 10.5ms inference, 6.6ms postprocess per image at shape (1, 3, 224, 320)
# 350
#
# 0: 320x224 1 face, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 224)
# 351
#
# 0: 320x224 1 face, 14.2ms
# Speed: 0.9ms preprocess, 14.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 224)
# 352
#
# 0: 256x320 1 face, 16.0ms
# Speed: 5.5ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 320)
# 353
#
# 0: 224x320 1 face, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 354
#
# 0: 224x320 1 face, 18.1ms
# Speed: 0.3ms preprocess, 18.1ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 320)
# 355
#
# 0: 224x320 1 face, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 4.8ms postprocess per image at shape (1, 3, 224, 320)
# 356
#
# 0: 224x320 1 face, 9.7ms
# Speed: 0.9ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 357
#
# 0: 320x224 1 face, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# 358
#
# 0: 224x320 1 face, 17.9ms
# Speed: 1.0ms preprocess, 17.9ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 320)
# 359
#
# 0: 256x320 1 face, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 320)
# 360
#
# 0: 224x320 1 face, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# 361
#
# 0: 224x320 1 face, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 362
#
# 0: 320x288 1 face, 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 288)
# 363
#
# 0: 320x224 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 224)
# 364
#
# 0: 224x320 (no detections), 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 365
#
# 0: 224x320 1 face, 8.1ms
# Speed: 0.9ms preprocess, 8.1ms inference, 9.1ms postprocess per image at shape (1, 3, 224, 320)
# 366
#
# 0: 224x320 1 face, 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)
# 367
#
# 0: 320x320 1 face, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 320)
# 368
#
# 0: 320x320 1 face, 45.9ms
# Speed: 6.4ms preprocess, 45.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# 369
#
# 0: 224x320 1 face, 32.9ms
# Speed: 0.0ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 370
#
# 0: 224x320 1 face, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 320)
# 371
#
# 0: 320x256 1 face, 12.5ms
# Speed: 0.7ms preprocess, 12.5ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 256)
# 372
#
# 0: 320x256 1 face, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 256)
# 373
#
# 0: 224x320 1 face, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 374
#
# 0: 224x320 1 face, 12.9ms
# Speed: 4.7ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
# 375
#
# 0: 224x320 1 face, 11.3ms
# ...
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2061
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# 2062
#
# 0: 320x320 1 face, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2063
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 320)
# 2064
#
# 0: 320x320 1 face, 19.5ms
# Speed: 0.0ms preprocess, 19.5ms inference, 10.6ms postprocess per image at shape (1, 3, 320, 320)
# 2065
#
# 0: 320x320 1 face, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2066
#
# 0: 320x320 1 face, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2067
#
# 0: 320x320 1 face, 8.6ms
# Speed: 0.0ms preprocess, 8.6ms inference, 15.8ms postprocess per image at shape (1, 3, 320, 320)
# 2068
#
# 0: 320x320 1 face, 16.7ms
# Speed: 15.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2069
#
# 0: 320x320 1 face, 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2070
#
# 0: 320x320 1 face, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 12.0ms postprocess per image at shape (1, 3, 320, 320)
# 2071
#
# 0: 320x320 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2072
#
# 0: 320x320 1 face, 31.4ms
# Speed: 0.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2073
#
# 0: 320x320 1 face, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2074
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 320)
# 2075
#
# 0: 320x320 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 15.5ms postprocess per image at shape (1, 3, 320, 320)
# 2076
#
# 0: 320x320 1 face, 6.5ms
# Speed: 15.5ms preprocess, 6.5ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 320)
# 2077
#
# 0: 320x320 1 face, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2078
#
# 0: 320x320 1 face, 22.3ms
# Speed: 0.0ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2079
#
# 0: 320x320 1 face, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2080
#
# 0: 320x320 1 face, 15.6ms
# Speed: 15.6ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2081
#
# 0: 320x320 1 face, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2082
#
# 0: 320x320 1 face, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2083
#
# 0: 320x320 1 face, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2084
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2085
#
# 0: 320x320 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2086
#
# 0: 320x320 1 face, 0.0ms
# Speed: 0.6ms preprocess, 0.0ms inference, 15.1ms postprocess per image at shape (1, 3, 320, 320)
# 2087
#
# 0: 320x320 1 face, 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 320)
# 2088
#
# 0: 320x320 1 face, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2089
#
# 0: 320x320 1 face, 20.4ms
# Speed: 2.7ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
# 2090
#
# 0: 320x320 1 face, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# 2091
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 320)
# 2092
#
# 0: 320x320 1 face, 14.7ms
# Speed: 4.0ms preprocess, 14.7ms inference, 9.3ms postprocess per image at shape (1, 3, 320, 320)
# 2093
#
# 0: 320x320 1 face, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# 2094
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2095
#
# 0: 320x320 1 face, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 320)
# 2096
#
# 0: 320x320 1 face, 17.1ms
# Speed: 1.1ms preprocess, 17.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 320)
# 2097
#
# 0: 320x320 1 face, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# 2098
#
# 0: 320x320 1 face, 24.0ms
# Speed: 2.5ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2099
#
# 0: 320x320 1 face, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# 2100
#
# 0: 320x320 1 face, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 320)
# 2101
#
# 0: 320x320 1 face, 21.5ms
# Speed: 2.8ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2102
#
# 0: 320x320 1 face, 29.1ms
# Speed: 2.2ms preprocess, 29.1ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 320)
# 2103
#
# 0: 320x320 1 face, 22.0ms
# Speed: 8.5ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2104
#
# 0: 320x320 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2105
#
# 0: 320x320 1 face, 22.2ms
# Speed: 10.6ms preprocess, 22.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2106
#
# 0: 320x320 1 face, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2107
#
# 0: 320x320 1 face, 10.2ms
# Speed: 3.7ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2108
#
# 0: 320x320 1 face, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2109
#
# 0: 320x320 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2110
#
# 0: 320x320 1 face, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2111
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2112
#
# 0: 320x320 1 face, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2113
#
# 0: 320x320 1 face, 14.3ms
# Speed: 1.6ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2114
#
# 0: 320x320 1 face, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 320)
# 2115
#
# 0: 320x320 1 face, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# 2116
#
# 0: 320x320 1 face, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 320)
# 2117
#
# 0: 320x320 1 face, 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 320)
# 2118
#
# 0: 320x320 1 face, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2119
#
# 0: 320x320 1 face, 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
# 2120
#
# 0: 320x320 1 face, 15.8ms
# Speed: 15.1ms preprocess, 15.8ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 320)
# 2121
#
# 0: 320x320 1 face, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2122
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2123
#
# 0: 320x320 1 face, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2124
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2125
#
# 0: 320x320 1 face, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2126
#
# 0: 320x320 1 face, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2127
#
# 0: 320x320 1 face, 17.2ms
# Speed: 0.0ms preprocess, 17.2ms inference, 14.0ms postprocess per image at shape (1, 3, 320, 320)
# 2128
#
# 0: 320x320 1 face, 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2129
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2130
#
# 0: 320x320 1 face, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2131
#
# 0: 320x320 1 face, 22.8ms
# Speed: 0.0ms preprocess, 22.8ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 320)
# 2132
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2133
#
# 0: 320x320 1 face, 9.1ms
# Speed: 6.9ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2134
#
# 0: 320x320 1 face, 19.9ms
# Speed: 0.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2135
#
# 0: 320x320 1 face, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2136
#
# 0: 320x320 1 face, 0.6ms
# Speed: 2.5ms preprocess, 0.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2137
#
# 0: 320x320 1 face, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2138
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2139
#
# 0: 320x320 1 face, 13.3ms
# Speed: 3.6ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2140
#
# 0: 320x320 1 face, 14.9ms
# Speed: 15.1ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2141
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2142
#
# 0: 320x320 1 face, 22.9ms
# Speed: 0.0ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
# 2143
#
# 0: 320x320 1 face, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2144
#
# 0: 320x320 1 face, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 14.5ms postprocess per image at shape (1, 3, 320, 320)
# 2145
#
# 0: 320x320 1 face, 23.7ms
# Speed: 0.0ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2146
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2147
#
# 0: 320x320 1 face, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 320)
# 2148
#
# 0: 320x320 1 face, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2149
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2150
#
# 0: 320x320 1 face, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 320)
# 2151
#
# 0: 320x320 1 face, 9.6ms
# Speed: 6.3ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2152
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2153
#
# 0: 320x320 1 face, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2154
#
# 0: 320x320 1 face, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2155
#
# 0: 320x320 1 face, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2156
#
# 0: 320x320 1 face, 26.7ms
# Speed: 0.0ms preprocess, 26.7ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 320)
# 2157
#
# 0: 320x320 1 face, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2158
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2159
#
# 0: 320x320 1 face, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2160
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2161
#
# 0: 320x320 1 face, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2162
#
# 0: 320x320 1 face, 18.0ms
# Speed: 15.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2163
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2164
#
# 0: 320x320 1 face, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2165
#
# 0: 320x320 1 face, 18.9ms
# Speed: 0.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2166
#
# 0: 320x320 1 face, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2167
#
# 0: 320x320 1 face, 29.8ms
# Speed: 0.0ms preprocess, 29.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 320)
# 2168
#
# 0: 320x320 1 face, 8.1ms
# Speed: 8.1ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2169
#
# 0: 320x320 1 face, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2170
#
# 0: 320x320 1 face, 29.4ms
# Speed: 0.0ms preprocess, 29.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
# 2171
#
# 0: 320x320 1 face, 30.7ms
# Speed: 0.0ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2172
#
# 0: 320x320 1 face, 9.6ms
# Speed: 13.3ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2173
#
# 0: 320x320 1 face, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2174
#
# 0: 320x320 1 face, 15.2ms
# Speed: 0.0ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2175
#
# 0: 320x320 1 face, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2176
#
# 0: 320x320 1 face, 15.8ms
# Speed: 14.1ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2177
#
# 0: 320x320 1 face, 24.8ms
# Speed: 0.0ms preprocess, 24.8ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 320)
# 2178
#
# 0: 320x320 1 face, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2179
#
# 0: 320x320 1 face, 1.8ms
# Speed: 17.3ms preprocess, 1.8ms inference, 14.6ms postprocess per image at shape (1, 3, 320, 320)
# 2180
#
# 0: 320x320 1 face, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 16.1ms postprocess per image at shape (1, 3, 320, 320)
# 2181
#
# 0: 320x320 1 face, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2182
#
# 0: 320x320 1 face, 31.4ms
# Speed: 0.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# 2183
#
# 0: 320x320 1 face, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)

# %%
all_preds[500]
# Out:
# ['49850110.jpg',
#  [660.0537109375, 295.8719482421875, 167.07867431640625, 249.24441528320312],
#  500,
#  'Caucasian',
#  '20-30s',
#  'Neutral',
#  'Female',
#  'light',
#  'unmasked']

# %%
# file_name,bbox,image_id,race,age,emotion,gender,skintone,masked
final = pd.DataFrame(columns= ['file_name', 'bbox', 'image_id', 'race', 'age', 'emotion', 'gender', 'skintone', 'masked'], data= all_preds)

# %%
final
# Out:
#            file_name                                               bbox
# 0      100147591.jpg  [1149.007080078125, 460.760498046875, 247.2583...  \
# 1      100429351.jpg  [591.6748046875, 303.05548095703125, 306.92004...
# 2      100473997.jpg  [646.132568359375, 282.62164306640625, 361.989...
# 3      100868012.jpg  [995.4942626953125, 237.6397247314453, 127.467...
# 4      101061106.jpg  [783.2681884765625, 229.55126953125, 302.63098...
# ...              ...                                                ...
# 2165  image_9841.jpg  [278.25, 213.11410522460938, 591.5426025390625...
# 2166  image_9913.jpg  [257.9833984375, 177.88156127929688, 558.03308...
# 2167  image_9915.jpg  [213.5572509765625, 176.28448486328125, 561.00...
# 2168  image_9935.jpg  [280.17083740234375, 163.39743041992188, 574.0...
# 2169  image_9975.jpg  [211.35467529296875, 160.0440673828125, 553.48...
#
#       image_id       race     age    emotion  gender skintone    masked
# 0            1  Caucasian  20-30s    Neutral  Female    light  unmasked
# 1            2  Mongoloid  20-30s    Neutral  Female    light  unmasked
# 2            3  Mongoloid  20-30s  Happiness  Female    light  unmasked
# 3            4  Mongoloid  20-30s  Happiness  Female    light  unmasked
# 4            6  Mongoloid  20-30s  Happiness  Female    light  unmasked
# ...        ...        ...     ...        ...     ...      ...       ...
# 2165      2180  Caucasian  20-30s  Happiness  Female    light  unmasked
# 2166      2181  Caucasian  20-30s  Happiness  Female    light  unmasked
# 2167      2182  Caucasian  20-30s  Happiness  Female    light  unmasked
# 2168      2183  Caucasian  20-30s  Happiness  Female    light  unmasked
# 2169      2184  Mongoloid  20-30s  Happiness  Female    light  unmasked
#
# [2170 rows x 9 columns]

# %%
final.to_csv('answer.csv', index= False)
