# %%
import pandas as pd

# %%
df = pd.read_csv('answer1.csv')
df
# Out:
#            file_name                   bbox  image_id       race     age  \
# 0       42777651.jpg  [681, 1192, 210, 194]       336  mongoloid  20-30s
# 1       64419591.jpg   [988, 320, 316, 393]       834  mongoloid     kid
# 2       88179407.jpg  [1417, 324, 193, 273]      1614  caucasian  20-30s
# 3     image_2603.jpg   [239, 154, 539, 858]      1850  caucasian  20-30s
# 4       69044640.jpg   [792, 311, 470, 596]       975  caucasian  20-30s
# ...              ...                    ...       ...        ...     ...
# 2205    83587904.jpg   [361, 319, 393, 474]      1478  caucasian    baby
# 2206    59309272.jpg  [1282, 129, 156, 216]       643  caucasian  20-30s
# 2207    54846073.jpg  [1036, 203, 165, 222]       559  caucasian  senior
# 2208    60313342.jpg   [412, 691, 188, 227]       675  caucasian  20-30s
# 2209    61565007.jpg   [895, 165, 189, 279]       715    negroid  20-30s
#
#         emotion  gender   skintone    masked
# 0     happiness  female  mid-light  unmasked
# 1       neutral  female  mid-light  unmasked
# 2     happiness    male  mid-light  unmasked
# 3     happiness    male  mid-light  unmasked
# 4       neutral  female  mid-light  unmasked
# ...         ...     ...        ...       ...
# 2205       fear  female      light  unmasked
# 2206    neutral    male      light  unmasked
# 2207    neutral    male  mid-light  unmasked
# 2208  happiness    male  mid-light  unmasked
# 2209    neutral    male  mid-light  unmasked
#
# [2210 rows x 9 columns]

# %%
s = 'asdasd'
s.title()
# Out:
# 'Asdasd'

# %%
df['race'] = df['race'].apply(lambda x: x.title())
df['age'] = df['age'].apply(lambda x: x.title())
df['emotion'] = df['emotion'].apply(lambda x: x.title())
df['gender'] = df['gender'].apply(lambda x: x.title())
df
# Out:
#            file_name                   bbox  image_id       race     age  \
# 0       42777651.jpg  [681, 1192, 210, 194]       336  Mongoloid  20-30S
# 1       64419591.jpg   [988, 320, 316, 393]       834  Mongoloid     Kid
# 2       88179407.jpg  [1417, 324, 193, 273]      1614  Caucasian  20-30S
# 3     image_2603.jpg   [239, 154, 539, 858]      1850  Caucasian  20-30S
# 4       69044640.jpg   [792, 311, 470, 596]       975  Caucasian  20-30S
# ...              ...                    ...       ...        ...     ...
# 2205    83587904.jpg   [361, 319, 393, 474]      1478  Caucasian    Baby
# 2206    59309272.jpg  [1282, 129, 156, 216]       643  Caucasian  20-30S
# 2207    54846073.jpg  [1036, 203, 165, 222]       559  Caucasian  Senior
# 2208    60313342.jpg   [412, 691, 188, 227]       675  Caucasian  20-30S
# 2209    61565007.jpg   [895, 165, 189, 279]       715    Negroid  20-30S
#
#         emotion  gender   skintone    masked
# 0     Happiness  Female  mid-light  unmasked
# 1       Neutral  Female  mid-light  unmasked
# 2     Happiness    Male  mid-light  unmasked
# 3     Happiness    Male  mid-light  unmasked
# 4       Neutral  Female  mid-light  unmasked
# ...         ...     ...        ...       ...
# 2205       Fear  Female      light  unmasked
# 2206    Neutral    Male      light  unmasked
# 2207    Neutral    Male  mid-light  unmasked
# 2208  Happiness    Male  mid-light  unmasked
# 2209    Neutral    Male  mid-light  unmasked
#
# [2210 rows x 9 columns]

# %%
df.to_csv('answer.csv', index=False)
