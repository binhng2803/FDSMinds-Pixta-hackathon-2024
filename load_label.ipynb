# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder

# %%
# img_list = os.listdir('E:\Pixta Hackathon\dataset\mnt\md0\projects\sami-hackathon\private\data/images')

# %%
def encode_label(file_name):
    df = pd.read_csv(file_name)
    le_dict_corrected = {column: LabelEncoder().fit(classes) for column, classes in df.items()}
    
    df_new_to_encode = df.drop(['file_name', 'height', 'width', 'bbox'], axis=1)

    # Apply the previously fitted LabelEncoders to the new dataframe
    df_new_encoded = df_new_to_encode.copy()
    for column, le in le_dict_corrected.items():
        if column in df_new_encoded:
            df_new_encoded[column] = le.transform(df_new_encoded[column])

    # Adding the non-encoded columns back to the encoded dataframe
    df_new_encoded['file_name'] = df['file_name']
    df_new_encoded['height'] = df['height']
    df_new_encoded['width'] = df['width']
    df_new_encoded['bbox'] = df['bbox']
    correct_column_order = ['file_name', 'height', 'width', 'bbox', 'age', 'race', 'masked', 'skintone', 'emotion', 'gender']

    # Reorder the columns in df_new_encoded to match the specified order
    df_correct_order = df_new_encoded[correct_column_order]

    return df_correct_order

encoded_df = encode_label("balance_label.csv")
encoded_df.to_csv("encoded_labels.csv", index= False)
encoded_df
# Out:
#              file_name  height  width
# 0        100013282.jpg    1333   2000  \
# 1        100016175.jpg    1333   2000
# 2         10004189.jpg    2000   1333
# 3        100104575.jpg    1333   2000
# 4        100104600.jpg    2000   1333
# ...                ...     ...    ...
# 16002  image_38213.jpg    1024   1024
# 16003  image_90933.jpg    1024   1024
# 16004  image_10043.jpg    1024   1024
# 16005  image_52433.jpg    1024   1024
# 16006  image_99893.jpg    1024   1024
#
#                                                     bbox  age  race  masked
# 0      [934.0000000000097, 144.82228672769534, 238.24...    0     0       1  \
# 1      [1094.0513571635438, 422.91772295627203, 55.45...    0     0       1
# 2      [419.93871061403877, 269.1250391680045, 377.19...    0     1       1
# 3      [1490.6909678848915, 676.0000000000097, 37.553...    0     0       1
# 4      [549.169724453414, 92.52040334013152, 306.8821...    0     0       1
# ...                                                  ...  ...   ...     ...
# 16002  [107.27759307562698, 232.83424166433173, 778.1...    1     2       1
# 16003  [427.83579238921163, 122.5697044206284, 504.62...    0     2       1
# 16004  [105.89913937262708, 25.783687099700543, 686.4...    1     2       1
# 16005  [0.0, 0.0, 934.1465333736514, 1000.0977173755459]    3     2       1
# 16006  [538.793770019496, 374.7044628081077, 485.2062...    0     2       1
#
#        skintone  emotion  gender
# 0             3        4       1
# 1             1        4       1
# 2             1        3       0
# 3             3        4       1
# 4             3        3       0
# ...         ...      ...     ...
# 16002         2        3       0
# 16003         2        3       0
# 16004         2        3       1
# 16005         2        3       0
# 16006         2        3       0
#
# [16007 rows x 10 columns]

# %%
detail   = {'age': {'20-30s': 0,
                '40-50s': 1,
                'Kid': 3,
                'Senior': 4,
                'Baby': 2,
                'Teenager': 5},
            'race': {'Caucasian': 0, 'Mongoloid': 1, 'Negroid': 2},
            'masked': {'unmasked': 1, 'Masked': 0},
            'skintone': {'mid-light': 3, 'light': 1, 'mid-dark': 2, 'Dark': 0},
            'emotion': {'Neutral': 4,
                        'Happiness': 3,
                        'Anger': 0,
                        'Surprise': 6,
                        'Fear': 2,
                        'Sadness': 5,
                        'Disgust': 1},
            'gender': {'Male': 1, 'Female': 0}}
